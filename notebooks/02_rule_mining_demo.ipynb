# %% [markdown]
# # Step 2: FP-Growth vs. Apriori Optimization
# Apriori's candidate generation scales at $O(2^d)$. We utilize FP-Growth to compress the dataset into a Frequent Pattern Tree, reducing runtime complexity to near $O(N)$.
# We then apply our proprietary Expected Commercial Value (ECV) metric to the output.

# %%
import sys
sys.path.append('..')  # Tells Python to look one folder up (the project root)

from src.fmcg_basket.engine import generate_synthetic_data, mine_rules_fpgrowth

# Generate data and mine rules
df, margins = generate_synthetic_data(100)
rules = mine_rules_fpgrowth(df, margins)
rules.head()
# Out:
# Generating 100 synthetic FMCG transactions...
# Mining association rules via FP-Growth...
# Optimization complete. Rules saved to data/processed/association_rules.csv
#     antecedents consequents  antecedent support  consequent support  support  \
# 390       Chips        Wine                0.02                0.49     0.02
# 158        Beer        Wine                0.03                0.49     0.03
# 383       Chips        Wine                0.03                0.49     0.03
# 62      Diapers        Wine                0.04                0.49     0.04
# 70   Baby Wipes        Wine                0.02                0.49     0.02
#
#      confidence      lift  representativity  leverage  conviction  \
# 390         1.0  2.040816               1.0    0.0102         inf
# 158         1.0  2.040816               1.0    0.0153         inf
# 383         1.0  2.040816               1.0    0.0153         inf
# 62          1.0  2.040816               1.0    0.0204         inf
# ...
