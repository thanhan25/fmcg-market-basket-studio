# %% [markdown]
# # Step 1: FMCG Data Ingestion & Formatting
# This notebook demonstrates how to connect to large-scale retail databases (e.g., BigQuery, Snowflake) or local Parquet files, pivoting transactional logs into the one-hot encoded matrix required for Frequent Pattern Mining.

# %%
# import pandas as pd
# import duckdb

# Note: This requires the parquet file to actually exist in data/raw/
# duckdb.sql("SELECT * FROM 'data/raw/transactions.parquet'")
print("Data ingestion pipeline ready.")
# Out:
# Data ingestion pipeline ready.
